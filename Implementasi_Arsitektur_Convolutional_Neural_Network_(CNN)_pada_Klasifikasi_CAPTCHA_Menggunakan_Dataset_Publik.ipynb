# %% [markdown]
# <a href="https://colab.research.google.com/github/salsabilhera/salsabilhera/blob/main/Implementasi_Arsitektur_Convolutional_Neural_Network_(CNN)_pada_Klasifikasi_CAPTCHA_Menggunakan_Dataset_Publik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Implementasi Arsitektur Convolutional Neural  Network (CNN) pada Klasifikasi CAPTCHA Menggunakan Dataset Publik**
#
# Salsabila Herapuspitaningrum Sastro
#
# 2106722726

# %% [markdown]
# # Image procesing

# %%
import cv2
import pandas
import seaborn
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fournierp/captcha-version-2-images")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2

# %%
path1 = '/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/23n88.png'
path2 = '/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/23mdg.png'

# %%
def plot_ (img1, img2) :
    plt.figure(figsize = (20,5))

    plt.subplot(1,2,1)
    plt.imshow(img1, 'gray')

    plt.axis('off')

    plt.subplot(1,2,2)
    plt.imshow(img2, 'gray')

    plt.axis('off')

# %%
img1 = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread(path2, cv2.IMREAD_GRAYSCALE)
plot_(img1, img2)

# %% [markdown]
# ### Adaptive Thresholding
# Algorithms determine the threshold for a pixel based on its surrounding regions. So we get different thresholds for different regions of the same image which gives better result for images with varying illumination.

# %%
thresh_img1 = cv2.adaptiveThreshold(img1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)
thresh_img2 = cv2.adaptiveThreshold(img2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)

# %%
plot_(thresh_img1, thresh_img2)

# %% [markdown]
# ### Closing
# Dilation followed by Erosion.

# %%
close_img1 = cv2.morphologyEx(thresh_img1, cv2.MORPH_CLOSE, np.ones((5,2), np.uint8))
close_img2 = cv2.morphologyEx(thresh_img2, cv2.MORPH_CLOSE, np.ones((5,2), np.uint8))

# %%
plot_(close_img1, close_img2)

# %% [markdown]
# ### Dilation
# Involves a kernel being scanned over the entire image. The maximal pixel value is calculated in the kernel region and the anchor point of the kernel is updated to that value. This causes the white region to expand in the image.

# %%
dilate_img1 = cv2.dilate(close_img1, np.ones((2,2), np.uint8), iterations = 1)
dilate_img2 = cv2.dilate(close_img2, np.ones((2,2), np.uint8), iterations = 1)

# %%
plot_(dilate_img1, dilate_img2)

# %% [markdown]
# ### Smoothing Images (Blurring)
# Involves convolving a low-pass filter with an image, to remove high frequency components ie. noises and edges from the image.

# %%
gauss_img1 = cv2.GaussianBlur(dilate_img1, (1,1), 0)
gauss_img2 = cv2.GaussianBlur(dilate_img2, (1,1), 0)

# %%
plot_(gauss_img1, gauss_img2)

# %% [markdown]
# ### PartitioningBatchNormalization

# %%
cv2.rectangle(gauss_img1, (30,12), (50,49), 0, 1)
cv2.rectangle(gauss_img1, (50,12), (70,49), 0, 1)
cv2.rectangle(gauss_img1, (70,12), (90,49), 0, 1)
cv2.rectangle(gauss_img1, (90,12), (110,49),0, 1)
cv2.rectangle(gauss_img1, (110,12),(130,49),0, 1)

cv2.rectangle(gauss_img2, (30,12), (50,49), 0, 1)
cv2.rectangle(gauss_img2, (50,12), (70,49), 0, 1)
cv2.rectangle(gauss_img2, (70,12), (90,49), 0, 1)
cv2.rectangle(gauss_img2, (90,12), (110,49),0, 1)
cv2.rectangle(gauss_img2, (110,12),(130,49),0, 1)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plot_(gauss_img1, gauss_img2)

# %% [markdown]
# # Converting images to appropriate samples

# %%
path = '/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/'

# %%
def t_img (img) :
    return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)

def c_img (img) :
    return cv2.morphologyEx(img, cv2.MORPH_CLOSE, np.ones((5,2), np.uint8))

def d_img (img) :
    return cv2.dilate(img, np.ones((2,2), np.uint8), iterations = 1)

def b_img (img) :
    return cv2.GaussianBlur(img, (1,1), 0)

# %%
import os
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator

# %%
X = []
y = []

for image in os.listdir(path) :

    if image[6:] != 'png' :
        continue

    img = cv2.imread(os.path.join(path, image), cv2.IMREAD_GRAYSCALE)

    img = t_img(img)
    img = c_img(img)
    img = d_img(img)
    img = b_img(img)

    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]

    for i in range(5) :
        X.append(img_to_array(Image.fromarray(image_list[i])))
        y.append(image[i])
X = np.array(X)
y = np.array(y)

# %%
print(X.shape)
print(y.shape)
# Out:
# (5200, 40, 20, 1)
# (5200,)

# %% [markdown]
# # Initial Analysis and Data Wrangling

# %% [markdown]
# ### Scale b/w 0 and 1

# %%
X /= 255.0

# %%
plt.figure(figsize = (20,5))
for i in range(5) :
    plt.subplot(1,5,i+1)
    plt.imshow(X[i], 'gray')
    plt.title('Label is ' + str(y[i]))
plt.plot()
# Out:
# []

# %%
temp = set(y)
for t in temp :
    print('Occurance count of ' + t + ' : ' + str(len(y[y == t])))
# Out:
# Occurance count of y : 232
# Occurance count of g : 271
# Occurance count of d : 259
# Occurance count of 6 : 259
# Occurance count of 2 : 265
# Occurance count of x : 264
# Occurance count of 3 : 267
# Occurance count of p : 253
# Occurance count of 7 : 258
# Occurance count of f : 271
# Occurance count of b : 240
# Occurance count of n : 525
# Occurance count of e : 235
# Occurance count of c : 262
# Occurance count of 4 : 284
# Occurance count of w : 235
# Occurance count of 5 : 281
# Occurance count of m : 275
# Occurance count of 8 : 264

# %%
 temp_df = pandas.DataFrame({'labels' : [t for t in temp], 'Count' : [len(y[y==t]) for t in temp]})

# %%
plt.figure(figsize = (20,7))
seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
plt.title('Label distribution in CAPTCHAS', fontsize = 20)
# Out:
# <ipython-input-26-c477dcff4fad>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
# Text(0.5, 1.0, 'Label distribution in CAPTCHAS')

# %% [markdown]
# The count of label **n** is almost twice as any other label, so more samples of this letter will be put in the test set.

# %% [markdown]
# ### One hot encoding

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Label Encoding
y_combine = LabelEncoder().fit_transform(y)

# One-Hot Encoding
y_one_hot = OneHotEncoder(sparse_output=False).fit_transform(y_combine.reshape(len(y_combine), 1))

# %%
print('letter n : ' + str(y[1]))
print('label : ' + str(y_combine[1]))
print('Count : ' + str(len(y_combine[y_combine == y_combine[1]])))
# Out:
# letter n : d
# label : 9
# Count : 259

# %%
info = {y_combine[i] : y[i] for i in range(len(y))}

# %% [markdown]
# # Train test split

# %%
print(X.shape)
print(y_one_hot.shape)  # one hot encoded form
# Out:
# (5200, 40, 20, 1)
# (5200, 19)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size = 0.2, random_state = 1)

# %%
y_temp = np.argmax(y_test, axis = 1)

# %%
temp = set(y_temp)
temp_df = pandas.DataFrame({'labels' : [info[t] for t in temp], 'Count' : [len(y_temp[y_temp == t]) for t in temp]})

# %%
plt.figure(figsize = (20,7))
seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
plt.title('Label distribution in test set', fontsize = 20)
# Out:
# <ipython-input-35-61f772194c12>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
# Text(0.5, 1.0, 'Label distribution in test set')

# %% [markdown]
# # Model Creation

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization

from keras.layers import Dropout
from keras.layers import Input

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4160, 40, 20, 1)
# (4160, 19)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1040, 40, 20, 1)
# (1040, 19)

# %%
def conv_layer (filterx) :

    model = Sequential()

    model.add(Conv2D(filterx, (3,3), padding = 'same', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))

    return model

# %%
def dens_layer (hiddenx) :

    model = Sequential()

    model.add(Dense(hiddenx, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    return model

# %%
def cnn (filter1, filter2, filter3, hidden1, hidden2) :

    model = Sequential()
    model.add(Input((40, 20, 1,)))

    model.add(conv_layer(filter1))
    model.add(conv_layer(filter2))
    model.add(conv_layer(filter3))

    model.add(Flatten())
    model.add(dens_layer(hidden1))
    model.add(dens_layer(hidden2))

    model.add(Dense(19, activation = 'softmax'))

    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    return model

# %% [markdown]
# # Data augmentation and Oversampling

# %% [markdown]
# ### SMOTE

# %%
X_train = np.reshape(X_train, (4160, 40*20*1))

# %%
from imblearn.over_sampling import SMOTE
X_train, y_train = SMOTE(sampling_strategy = 'auto', random_state = 1).fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (7904, 800)
# (7904, 19)

# %%
print(X_train.shape)
print(X_train.size)
# Out:
# (7904, 800)
# 6323200

# %%
X_train = np.reshape(X_train, (7904, 40, 20, 1))

# %% [markdown]
# Oversampled images

# %%
plt.figure(figsize = (20,20))

hi = 7800
lo = 5000

for i in range(25) :
    plt.subplot(5,5,i+1)
    x = np.random.randint(lo, hi)
    plt.imshow(X_train[x], 'gray')
    plt.title('Label is ' + str(info[np.argmax(y_train[x])]))
plt.show()

# %% [markdown]
# ### ImageDataGenerator

# %%
traingen = ImageDataGenerator(rotation_range = 5, width_shift_range = [-2,2])
traingen.fit(X_train)

# %%
train_set = traingen.flow(X_train, y_train)

# %%
trainX, trainy = train_set.__next__()

# %% [markdown]
# Augmented images with rotations and shifts.

# %%
plt.figure(figsize = (20,20))

hi = 32
lo = 0

for i in range(25) :
    plt.subplot(5,5,i+1)
    x = np.random.randint(lo, hi)
    plt.imshow(trainX[x], 'gray')
    plt.title('Label is ' + str(info[np.argmax(trainy[x])]))
plt.show()

# %% [markdown]
# # Model Training

# %%
model = cnn(128, 32, 16, 32, 32)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 20, 10, 128)         │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_2 (Sequential)            │ (None, 10, 5, 32)           │          37,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_3 (Sequential)            │ (None, 5, 3, 16)            │           4,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 240)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_4 (Sequential)            │ (None, 32)                  │           7,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_5 (Sequential)            │ (None, 32)                  │           1,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 19)                  │             627 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 53,155 (207.64 KB)
#  Trainable params: 52,675 (205.76 KB)
#  Non-trainable params: 480 (1.88 KB)

# %% [markdown]
# ### ModelCheckpoint and ReduceLROnPlateau
# Used ModelCheckpoint to retain the best perfroming model (in terms of loss), and ReduceLROnPlateau to reduce the learning in case the model stops improving.

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
checkp = ModelCheckpoint('./result_model.keras', monitor='val_loss', verbose=1, save_best_only=True)

# %%
reduce = ReduceLROnPlateau(monitor = 'val_loss', patience = 20, verbose = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (7904, 40, 20, 1)
# (7904, 19)

# %%
steps_per_epoch = int(len(X_train) / 32)

# %%
history = model.fit(
    traingen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_test, y_test),
    epochs=10,
    steps_per_epoch=steps_per_epoch,
    callbacks=[checkp])
# Out:
# Epoch 1/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8057 - loss: 0.6791
# Epoch 1: val_loss improved from 0.64171 to 0.62895, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 51s 206ms/step - accuracy: 0.8057 - loss: 0.6790 - val_accuracy: 0.8231 - val_loss: 0.6290
# Epoch 2/50
#
# Epoch 2: val_loss did not improve from 0.62895
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8231 - val_loss: 0.6290
# Epoch 3/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8145 - loss: 0.6380
# Epoch 3: val_loss did not improve from 0.62895
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.8145 - loss: 0.6380 - val_accuracy: 0.8327 - val_loss: 0.6327
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.62895
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8327 - val_loss: 0.6327
# Epoch 5/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8339 - loss: 0.5685
# Epoch 5: val_loss improved from 0.62895 to 0.53987, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 85s 219ms/step - accuracy: 0.8339 - loss: 0.5686 - val_accuracy: 0.8625 - val_loss: 0.5399
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8625 - val_loss: 0.5399
# Epoch 7/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8413 - loss: 0.5486
# Epoch 7: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 80s 219ms/step - accuracy: 0.8414 - loss: 0.5485 - val_accuracy: 0.8413 - val_loss: 0.5903
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8413 - val_loss: 0.5903
# Epoch 9/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8490 - loss: 0.5240
# Epoch 9: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 204ms/step - accuracy: 0.8490 - loss: 0.5240 - val_accuracy: 0.8490 - val_loss: 0.5779
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8490 - val_loss: 0.5779
# Epoch 11/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8535 - loss: 0.5065
# Epoch 11: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.8535 - loss: 0.5065 - val_accuracy: 0.7952 - val_loss: 0.7068
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7952 - val_loss: 0.7068
# Epoch 13/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8570 - loss: 0.4821
# Epoch 13: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 54s 217ms/step - accuracy: 0.8569 - loss: 0.4821 - val_accuracy: 0.8423 - val_loss: 0.5777
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8423 - val_loss: 0.5777
# Epoch 15/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8599 - loss: 0.4698
# Epoch 15: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 49s 200ms/step - accuracy: 0.8599 - loss: 0.4698 - val_accuracy: 0.8337 - val_loss: 0.6058
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.53987
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8337 - val_loss: 0.6058
# Epoch 17/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8649 - loss: 0.4449
# Epoch 17: val_loss improved from 0.53987 to 0.52338, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.8649 - loss: 0.4449 - val_accuracy: 0.8529 - val_loss: 0.5234
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.52338
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8529 - val_loss: 0.5234
# Epoch 19/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8724 - loss: 0.4225
# Epoch 19: val_loss did not improve from 0.52338
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8724 - loss: 0.4226 - val_accuracy: 0.8500 - val_loss: 0.5287
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.52338
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8500 - val_loss: 0.5287
# Epoch 21/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8626 - loss: 0.4510
# Epoch 21: val_loss improved from 0.52338 to 0.49794, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 81s 209ms/step - accuracy: 0.8626 - loss: 0.4510 - val_accuracy: 0.8644 - val_loss: 0.4979
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.49794
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8644 - val_loss: 0.4979
# Epoch 23/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8759 - loss: 0.3985
# Epoch 23: val_loss improved from 0.49794 to 0.48871, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 80s 206ms/step - accuracy: 0.8759 - loss: 0.3986 - val_accuracy: 0.8683 - val_loss: 0.4887
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.48871
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8683 - val_loss: 0.4887
# Epoch 25/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8804 - loss: 0.4139
# Epoch 25: val_loss did not improve from 0.48871
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 48s 195ms/step - accuracy: 0.8804 - loss: 0.4139 - val_accuracy: 0.8654 - val_loss: 0.5110
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.48871
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8654 - val_loss: 0.5110
# Epoch 27/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8814 - loss: 0.4099
# Epoch 27: val_loss did not improve from 0.48871
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.8814 - loss: 0.4099 - val_accuracy: 0.7115 - val_loss: 0.9596
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.48871
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7115 - val_loss: 0.9596
# Epoch 29/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8814 - loss: 0.4090
# Epoch 29: val_loss improved from 0.48871 to 0.46313, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 0.8814 - loss: 0.4090 - val_accuracy: 0.8712 - val_loss: 0.4631
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.46313
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8712 - val_loss: 0.4631
# Epoch 31/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8844 - loss: 0.3842
# Epoch 31: val_loss improved from 0.46313 to 0.46165, saving model to ./result_model.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 80s 206ms/step - accuracy: 0.8844 - loss: 0.3842 - val_accuracy: 0.8721 - val_loss: 0.4617
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8721 - val_loss: 0.4617
# Epoch 33/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8774 - loss: 0.3961
# Epoch 33: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 47s 191ms/step - accuracy: 0.8774 - loss: 0.3961 - val_accuracy: 0.8327 - val_loss: 0.5651
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8327 - val_loss: 0.5651
# Epoch 35/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8837 - loss: 0.3867
# Epoch 35: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.8838 - loss: 0.3867 - val_accuracy: 0.8644 - val_loss: 0.4852
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8644 - val_loss: 0.4852
# Epoch 37/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8902 - loss: 0.3936
# Epoch 37: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 80s 198ms/step - accuracy: 0.8902 - loss: 0.3936 - val_accuracy: 0.8788 - val_loss: 0.4848
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8788 - val_loss: 0.4848
# Epoch 39/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8951 - loss: 0.3547
# Epoch 39: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 81s 198ms/step - accuracy: 0.8951 - loss: 0.3548 - val_accuracy: 0.8173 - val_loss: 0.6398
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8173 - val_loss: 0.6398
# Epoch 41/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8831 - loss: 0.3813
# Epoch 41: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.8831 - loss: 0.3812 - val_accuracy: 0.8702 - val_loss: 0.5257
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8702 - val_loss: 0.5257
# Epoch 43/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8885 - loss: 0.3525
# Epoch 43: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 84s 207ms/step - accuracy: 0.8885 - loss: 0.3525 - val_accuracy: 0.8654 - val_loss: 0.4924
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8654 - val_loss: 0.4924
# Epoch 45/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8958 - loss: 0.3640
# Epoch 45: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 81s 208ms/step - accuracy: 0.8958 - loss: 0.3640 - val_accuracy: 0.8548 - val_loss: 0.5300
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8548 - val_loss: 0.5300
# Epoch 47/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8917 - loss: 0.3543
# Epoch 47: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.8917 - loss: 0.3543 - val_accuracy: 0.8673 - val_loss: 0.4916
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8673 - val_loss: 0.4916
# Epoch 49/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8969 - loss: 0.3208
# Epoch 49: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 81s 200ms/step - accuracy: 0.8968 - loss: 0.3209 - val_accuracy: 0.8663 - val_loss: 0.5072
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.46165
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8663 - val_loss: 0.5072

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.legend(['train loss','val loss'])
plt.title('Loss function wrt epochs')

plt.subplot(2,1,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train acc' , 'val acc'])
plt.title('Model accuracy wrt Epoch')
# Out:
# Text(0.5, 1.0, 'Model accuracy wrt Epoch')

# %% [markdown]
# # Prediction

# %%
from keras.models import load_model

# %%
model = load_model('./result_model.keras')

# %%
pred = model.predict(X_test)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %% [markdown]
# Perfromed numpy argmax to obtain the value which has the highest probability of being the truth value.

# %%
pred = np.argmax(pred, axis = 1)
yres = np.argmax(y_test,axis= 1)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
target_name = []
for i in sorted(info) :
    target_name.append(info[i])

# %%
target_name
# Out:
# ['2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'm',
#  'n',
#  'p',
#  'w',
#  'x',
#  'y']

# %%
print('Accuracy : ' + str(accuracy_score(yres, pred)))
print(classification_report(yres, pred, target_names = target_name))
# Out:
# Accuracy : 0.8721153846153846
#               precision    recall  f1-score   support
#
#            2       0.91      0.84      0.88        38
#            3       1.00      0.82      0.90        49
#            4       0.92      1.00      0.96        65
#            5       0.95      0.87      0.91        63
#            6       0.92      0.89      0.91        54
#            7       0.97      0.90      0.94        42
#            8       0.87      0.96      0.91        50
#            b       0.94      0.91      0.92        54
#            c       0.78      0.82      0.80        49
#            d       0.85      0.92      0.89        51
#            e       0.95      0.77      0.85        47
#            f       0.86      0.95      0.90        58
#            g       0.89      0.98      0.93        42
#            m       0.91      0.33      0.48        64
#            n       0.70      0.92      0.79       109
#            p       0.89      0.98      0.94        60
#            w       0.70      0.95      0.81        44
#            x       0.98      0.87      0.92        55
#            y       1.00      0.93      0.97        46
#
#     accuracy                           0.87      1040
#    macro avg       0.90      0.87      0.87      1040
# weighted avg       0.89      0.87      0.87      1040

# %% [markdown]
# # Testing on samples

# %%
def get_demo (img_path) :

    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.show()

    img = t_img(img)
    img = c_img(img)
    img = d_img(img)
    img = b_img(img)

    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]

    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.show()
    Xdemo = []
    for i in range(5) :
        Xdemo.append(img_to_array(Image.fromarray(image_list[i])))

    Xdemo = np.array(Xdemo)
    Xdemo/= 255.0

    ydemo = model.predict(Xdemo)
    ydemo = np.argmax(ydemo, axis = 1)

    for res in ydemo :
        print(info[res])
    print(img_path[-9:])

# %% [markdown]
# #### Samples for which model identified correctly.

# %%
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/2g783.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/2fxgd.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/88bgx.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/4yc85.png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2
# g
# 7
# 8
# 3
# 2g783.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2
# f
# x
# g
# d
# 2fxgd.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 8
# 8
# b
# g
# x
# 88bgx.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4
# y
# c
# 8
# 5
# 4yc85.png

# %% [markdown]
# #### Samples where model made errors while identification.

# %%
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/3g2w6.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/7wnpm.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/2mpnn.png')
get_demo('/root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2/samples/53mn8.png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 3
# g
# 2
# w
# n
# 3g2w6.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 7
# w
# n
# p
# n
# 7wnpm.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2
# n
# p
# p
# m
# 2mpnn.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 5
# 3
# n
# m
# 8
# 53mn8.png
